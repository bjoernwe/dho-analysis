// %% [markdown]
// # Hello World
//
// This notebook imports `hello.Greeter` from the project's compiled JAR.
//
// Build the JAR first:
// ```
// cd .. && ./gradlew jar
// ```

// %%
@file:DependsOn("../build/libs/dho-kotlin-1.0.jar")

// %%
import hello.Greeter
import hello.greet

// top-level function
println(greet("World"))

// class
val greeter = Greeter("Hi")
println(greeter.greet("Kotlin"))
// Out:
// Hello, World!
// Hi, Kotlin!
