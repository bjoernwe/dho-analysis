// %% [markdown]
// ## SFA loadings
//
// Visualizes `data/sentence_sfa_loadings.csv` — for each zero-shot label, its *effective* loading on
// the first 5 slow features (see `experiments/CalcSentenceSfa.kt`). The loadings compose the whole
// chain PCA -> SFA, so they express each slow feature directly in raw label space. One horizontal bar
// chart per feature, bars sorted by loading value, colored on a diverging scale centered at zero.
//
// For each slow feature, also visualizes the most/least representative sentences from
// `data/sentence_sfa_features.csv` — the sentences whose score on that feature is highest and lowest.
//
// Slow features are ordered by slowness: `sf1` is the label-space direction that changes most slowly
// from practice-log post to post, `sf5` the fastest of the five.

// %%
%useLatestDescriptors
%use dataframe
%use kandy

// %%
val loadings = DataFrame.readCsv("../data/sentence_sfa_loadings.csv")
println("Rows: ${loadings.rowsCount()}, columns: ${loadings.columnNames()}")
loadings.head()
// Out:
// kotlin-logging: initializing... active logger factory: Slf4jLoggerFactory
// Rows: 70, columns: [label, sf1, sf2, sf3, sf4, sf5]
//             <iframe onload="o_resize_iframe_out_1()" style="width:100%;" class="result_container" id="iframe_out_1" frameBorder="0" srcdoc="        &lt;html theme='dark'&gt;
//         &lt;head&gt;
//             &lt;style type=&quot;text&sol;css&quot;&gt;
//                 :root {
//     --background: #fff;
//     --background-odd: #f5f5f5;
//     --background-hover: #d9edfd;
//     --header-text-color: #474747;
//     --text-color: #848484;
//     --text-color-dark: #000;
//     --text-color-medium: #737373;
//     --text-color-pale: #b3b3b3;
//     --inner-border-color: #aaa;
//     --bold-border-color: #000;
//     --link-color: #296eaa;
//     --link-color-pale: #296eaa;
//     --link-hover: #1a466c;
// }
//
// :root[theme=&quot;dark&quot;], :root [data-jp-theme-light=&quot;false&quot;], .dataframe_dark{
//     --background: #303030;
//     --background-odd: #3c3c3c;
//     --background-hover: #464646;
//     --header-text-color: #dddddd;
//     --text-color: #b3b3b3;
//     --text-color-dark: #dddddd;
//     --text-color-medium: #b2b2b2;
//     --text-color-pale: #737373;
//     --inner-border-color: #707070;
//     --bold-border-color: #777777;
//     --link-color: #008dc0;
//     --link-color-pale: #97e1fb;
//     --link-hover: #00688e;
// }
//
// p.dataframe_description {
//     color: var(--text-color-dark);
// }
//
// table.dataframe {
//     font-family: &quot;Helvetica Neue&quot;, Helvetica, Arial, sans-serif;
//     font-size: 12px;
//     background-color: var(--background);
//     color: var(--text-color-dark);
//     border: none;
//     border-collapse: collapse;
// }
//
// table.dataframe th, td {
//     padding: 6px;
//     border: 1px solid transparent;
//     text-align: left;
// }
//
// table.dataframe th {
//     background-color: var(--background);
//     color: var(--header-text-color);
// }
//
// table.dataframe td {
//     vertical-align: top;
//     white-space: nowrap;
// }
//
// table.dataframe th.bottomBorder {
//     border-bottom-color: var(--bold-border-color);
// }
//
// table.dataframe tbody &gt; tr:nth-child(odd) {
//     background: var(--background-odd);
// }
//
// table.dataframe tbody &gt; tr:nth-child(even) {
//     background: var(--background);
// }
//
// table.dataframe tbody &gt; tr:hover {
//     background: var(--background-hover);
// }
//
// table.dataframe a {
//     cursor: pointer;
//     color: var(--link-color);
//     text-decoration: none;
// }
//
// table.dataframe tr:hover &gt; td a {
//     color: var(--link-color-pale);
// }
//
// table.dataframe a:hover {
//     color: var(--link-hover);
//     text-decoration: underline;
// }
//
// table.dataframe img {
//     max-width: fit-content;
// }
//
// table.dataframe th.complex {
//     background-color: var(--background);
//     border: 1px solid var(--background);
// }
//
// table.dataframe .leftBorder {
//     border-left-color: var(--inner-border-color);
// }
//
// table.dataframe .rightBorder {
//     border-right-color: var(--inner-border-color);
// }
//
// table.dataframe .rightAlign {
//     text-align: right;
// }
//
// table.dataframe .expanderSvg {
//     width: 8px;
//     height: 8px;
//     margin-right: 3px;
// }
//
// table.dataframe .expander {
//     display: flex;
//     align-items: center;
// }
//
// &sol;* formatting *&sol;
//
// table.dataframe .null {
//     color: var(--text-color-pale);
// }
//
// table.dataframe .structural {
//     color: var(--text-color-medium);
//     font-weight: bold;
// }
//
// table.dataframe .dataFrameCaption {
//     font-weight: bold;
// }
//
// table.dataframe .numbers {
//     color: var(--text-color-dark);
// }
//
// table.dataframe td:hover .formatted .structural, .null {
//     color: var(--text-color-dark);
// }
//
// table.dataframe tr:hover .formatted .structural, .null {
//     color: var(--text-color-dark);
// }
//
//
// :root {
//     --scroll-bg: #f5f5f5;
//     --scroll-fg: #b3b3b3;
// }
// :root[theme=&quot;dark&quot;], :root [data-jp-theme-light=&quot;false&quot;]{
//     --scroll-bg: #3c3c3c;
//     --scroll-fg: #97e1fb;
// }
// body {
//     scrollbar-color: var(--scroll-fg) var(--scroll-bg);
// }
// body::-webkit-scrollbar {
//     width: 10px; &sol;* Mostly for vertical scrollbars *&sol;
//     height: 10px; &sol;* Mostly for horizontal scrollbars *&sol;
// }
// body::-webkit-scrollbar-thumb {
//     background-color: var(--scroll-fg);
// }
// body::-webkit-scrollbar-track {
//     background-color: var(--scroll-bg);
// }
//             &lt;&sol;style&gt;
//         &lt;&sol;head&gt;
//         &lt;body&gt;
//             &lt;table class=&quot;dataframe&quot; id=&quot;df_167772160&quot;&gt;&lt;&sol;table&gt;
//
// &lt;p class=&quot;dataframe_description&quot;&gt;DataFrame: rowsCount = 5, columnsCount = 6&lt;&sol;p&gt;
//
//         &lt;&sol;body&gt;
//         &lt;script&gt;
//             (function () {
//     window.DataFrame = window.DataFrame || new (function () {
//         this.addTable = function (df) {
//             let cols = df.cols;
//             for (let i = 0; i &lt; cols.length; i++) {
//                 for (let c of cols[i].children) {
//                     cols[c].parent = i;
//                 }
//             }
//             df.nrow = 0
//             for (let i = 0; i &lt; df.cols.length; i++) {
//                 if (df.cols[i].values.length &gt; df.nrow) df.nrow = df.cols[i].values.length
//             }
//             if (df.id === df.rootId) {
//                 df.expandedFrames = new Set()
//                 df.childFrames = {}
//                 const table = this.getTableElement(df.id)
//                 table.df = df
//                 for (let i = 0; i &lt; df.cols.length; i++) {
//                     let col = df.cols[i]
//                     if (col.parent === undefined &amp;&amp; col.children.length &gt; 0) col.expanded = true
//                 }
//             } else {
//                 const rootDf = this.getTableData(df.rootId)
//                 rootDf.childFrames[df.id] = df
//             }
//         }
//
//         this.computeRenderData = function (df) {
//             let result = []
//             let pos = 0
//             for (let col = 0; col &lt; df.cols.length; col++) {
//                 if (df.cols[col].parent === undefined)
//                     pos += this.computeRenderDataRec(df.cols, col, pos, 0, result, false, false)
//             }
//             for (let i = 0; i &lt; result.length; i++) {
//                 let row = result[i]
//                 for (let j = 0; j &lt; row.length; j++) {
//                     let cell = row[j]
//                     if (j === 0)
//                         cell.leftBd = false
//                     if (j &lt; row.length - 1) {
//                         let nextData = row[j + 1]
//                         if (nextData.leftBd) cell.rightBd = true
//                         else if (cell.rightBd) nextData.leftBd = true
//                     } else cell.rightBd = false
//                 }
//             }
//             return result
//         }
//
//         this.computeRenderDataRec = function (cols, colId, pos, depth, result, leftBorder, rightBorder) {
//             if (result.length === depth) {
//                 const array = [];
//                 if (pos &gt; 0) {
//                     let j = 0
//                     for (let i = 0; j &lt; pos; i++) {
//                         let c = result[depth - 1][i]
//                         j += c.span
//                         let copy = Object.assign({empty: true}, c)
//                         array.push(copy)
//                     }
//                 }
//                 result.push(array)
//             }
//             const col = cols[colId];
//             let size = 0;
//             if (col.expanded) {
//                 let childPos = pos
//                 for (let i = 0; i &lt; col.children.length; i++) {
//                     let child = col.children[i]
//                     let childLeft = i === 0 &amp;&amp; (col.children.length &gt; 1 || leftBorder)
//                     let childRight = i === col.children.length - 1 &amp;&amp; (col.children.length &gt; 1 || rightBorder)
//                     let childSize = this.computeRenderDataRec(cols, child, childPos, depth + 1, result, childLeft, childRight)
//                     childPos += childSize
//                     size += childSize
//                 }
//             } else {
//                 for (let i = depth + 1; i &lt; result.length; i++)
//                     result[i].push({id: colId, span: 1, leftBd: leftBorder, rightBd: rightBorder, empty: true})
//                 size = 1
//             }
//             let left = leftBorder
//             let right = rightBorder
//             if (size &g

// %%
fun plotLoadings(component: String) = run {
    val sorted = loadings.sortBy(component)
    val labels = sorted["label"].toList().map { it.toString() }
    val values = sorted[component].toList().map { (it as Number).toDouble() }

    plot {
        layout {
            title = "Label weights in SFA component \"$component\""
            size = 700 to 1600
        }
        barsH {
            y(labels) { axis.name = "label" }
            x(values) { axis.name = "loading" }
            fillColor(values) {
                scale = continuousColorGradient2(Color.BLUE, Color.WHITE, Color.RED, 0.0)
                legend.name = "loading"
            }
        }
    }
}

// %%
val features = DataFrame.readCsv("../data/sentence_sfa_features.csv").distinctBy("sentence")
println("Rows: ${features.rowsCount()}, columns: ${features.columnNames()}")
features.head()
// Out:
// Rows: 33428, columns: [msgId, date, sentence, sf1, sf2, sf3, sf4, sf5]
//             <iframe onload="o_resize_iframe_out_2()" style="width:100%;" class="result_container" id="iframe_out_2" frameBorder="0" srcdoc="        &lt;html theme='dark'&gt;
//         &lt;head&gt;
//             &lt;style type=&quot;text&sol;css&quot;&gt;
//                 :root {
//     --background: #fff;
//     --background-odd: #f5f5f5;
//     --background-hover: #d9edfd;
//     --header-text-color: #474747;
//     --text-color: #848484;
//     --text-color-dark: #000;
//     --text-color-medium: #737373;
//     --text-color-pale: #b3b3b3;
//     --inner-border-color: #aaa;
//     --bold-border-color: #000;
//     --link-color: #296eaa;
//     --link-color-pale: #296eaa;
//     --link-hover: #1a466c;
// }
//
// :root[theme=&quot;dark&quot;], :root [data-jp-theme-light=&quot;false&quot;], .dataframe_dark{
//     --background: #303030;
//     --background-odd: #3c3c3c;
//     --background-hover: #464646;
//     --header-text-color: #dddddd;
//     --text-color: #b3b3b3;
//     --text-color-dark: #dddddd;
//     --text-color-medium: #b2b2b2;
//     --text-color-pale: #737373;
//     --inner-border-color: #707070;
//     --bold-border-color: #777777;
//     --link-color: #008dc0;
//     --link-color-pale: #97e1fb;
//     --link-hover: #00688e;
// }
//
// p.dataframe_description {
//     color: var(--text-color-dark);
// }
//
// table.dataframe {
//     font-family: &quot;Helvetica Neue&quot;, Helvetica, Arial, sans-serif;
//     font-size: 12px;
//     background-color: var(--background);
//     color: var(--text-color-dark);
//     border: none;
//     border-collapse: collapse;
// }
//
// table.dataframe th, td {
//     padding: 6px;
//     border: 1px solid transparent;
//     text-align: left;
// }
//
// table.dataframe th {
//     background-color: var(--background);
//     color: var(--header-text-color);
// }
//
// table.dataframe td {
//     vertical-align: top;
//     white-space: nowrap;
// }
//
// table.dataframe th.bottomBorder {
//     border-bottom-color: var(--bold-border-color);
// }
//
// table.dataframe tbody &gt; tr:nth-child(odd) {
//     background: var(--background-odd);
// }
//
// table.dataframe tbody &gt; tr:nth-child(even) {
//     background: var(--background);
// }
//
// table.dataframe tbody &gt; tr:hover {
//     background: var(--background-hover);
// }
//
// table.dataframe a {
//     cursor: pointer;
//     color: var(--link-color);
//     text-decoration: none;
// }
//
// table.dataframe tr:hover &gt; td a {
//     color: var(--link-color-pale);
// }
//
// table.dataframe a:hover {
//     color: var(--link-hover);
//     text-decoration: underline;
// }
//
// table.dataframe img {
//     max-width: fit-content;
// }
//
// table.dataframe th.complex {
//     background-color: var(--background);
//     border: 1px solid var(--background);
// }
//
// table.dataframe .leftBorder {
//     border-left-color: var(--inner-border-color);
// }
//
// table.dataframe .rightBorder {
//     border-right-color: var(--inner-border-color);
// }
//
// table.dataframe .rightAlign {
//     text-align: right;
// }
//
// table.dataframe .expanderSvg {
//     width: 8px;
//     height: 8px;
//     margin-right: 3px;
// }
//
// table.dataframe .expander {
//     display: flex;
//     align-items: center;
// }
//
// &sol;* formatting *&sol;
//
// table.dataframe .null {
//     color: var(--text-color-pale);
// }
//
// table.dataframe .structural {
//     color: var(--text-color-medium);
//     font-weight: bold;
// }
//
// table.dataframe .dataFrameCaption {
//     font-weight: bold;
// }
//
// table.dataframe .numbers {
//     color: var(--text-color-dark);
// }
//
// table.dataframe td:hover .formatted .structural, .null {
//     color: var(--text-color-dark);
// }
//
// table.dataframe tr:hover .formatted .structural, .null {
//     color: var(--text-color-dark);
// }
//
//
// :root {
//     --scroll-bg: #f5f5f5;
//     --scroll-fg: #b3b3b3;
// }
// :root[theme=&quot;dark&quot;], :root [data-jp-theme-light=&quot;false&quot;]{
//     --scroll-bg: #3c3c3c;
//     --scroll-fg: #97e1fb;
// }
// body {
//     scrollbar-color: var(--scroll-fg) var(--scroll-bg);
// }
// body::-webkit-scrollbar {
//     width: 10px; &sol;* Mostly for vertical scrollbars *&sol;
//     height: 10px; &sol;* Mostly for horizontal scrollbars *&sol;
// }
// body::-webkit-scrollbar-thumb {
//     background-color: var(--scroll-fg);
// }
// body::-webkit-scrollbar-track {
//     background-color: var(--scroll-bg);
// }
//             &lt;&sol;style&gt;
//         &lt;&sol;head&gt;
//         &lt;body&gt;
//             &lt;table class=&quot;dataframe&quot; id=&quot;df_167772162&quot;&gt;&lt;&sol;table&gt;
//
// &lt;p class=&quot;dataframe_description&quot;&gt;DataFrame: rowsCount = 5, columnsCount = 8&lt;&sol;p&gt;
//
//         &lt;&sol;body&gt;
//         &lt;script&gt;
//             (function () {
//     window.DataFrame = window.DataFrame || new (function () {
//         this.addTable = function (df) {
//             let cols = df.cols;
//             for (let i = 0; i &lt; cols.length; i++) {
//                 for (let c of cols[i].children) {
//                     cols[c].parent = i;
//                 }
//             }
//             df.nrow = 0
//             for (let i = 0; i &lt; df.cols.length; i++) {
//                 if (df.cols[i].values.length &gt; df.nrow) df.nrow = df.cols[i].values.length
//             }
//             if (df.id === df.rootId) {
//                 df.expandedFrames = new Set()
//                 df.childFrames = {}
//                 const table = this.getTableElement(df.id)
//                 table.df = df
//                 for (let i = 0; i &lt; df.cols.length; i++) {
//                     let col = df.cols[i]
//                     if (col.parent === undefined &amp;&amp; col.children.length &gt; 0) col.expanded = true
//                 }
//             } else {
//                 const rootDf = this.getTableData(df.rootId)
//                 rootDf.childFrames[df.id] = df
//             }
//         }
//
//         this.computeRenderData = function (df) {
//             let result = []
//             let pos = 0
//             for (let col = 0; col &lt; df.cols.length; col++) {
//                 if (df.cols[col].parent === undefined)
//                     pos += this.computeRenderDataRec(df.cols, col, pos, 0, result, false, false)
//             }
//             for (let i = 0; i &lt; result.length; i++) {
//                 let row = result[i]
//                 for (let j = 0; j &lt; row.length; j++) {
//                     let cell = row[j]
//                     if (j === 0)
//                         cell.leftBd = false
//                     if (j &lt; row.length - 1) {
//                         let nextData = row[j + 1]
//                         if (nextData.leftBd) cell.rightBd = true
//                         else if (cell.rightBd) nextData.leftBd = true
//                     } else cell.rightBd = false
//                 }
//             }
//             return result
//         }
//
//         this.computeRenderDataRec = function (cols, colId, pos, depth, result, leftBorder, rightBorder) {
//             if (result.length === depth) {
//                 const array = [];
//                 if (pos &gt; 0) {
//                     let j = 0
//                     for (let i = 0; j &lt; pos; i++) {
//                         let c = result[depth - 1][i]
//                         j += c.span
//                         let copy = Object.assign({empty: true}, c)
//                         array.push(copy)
//                     }
//                 }
//                 result.push(array)
//             }
//             const col = cols[colId];
//             let size = 0;
//             if (col.expanded) {
//                 let childPos = pos
//                 for (let i = 0; i &lt; col.children.length; i++) {
//                     let child = col.children[i]
//                     let childLeft = i === 0 &amp;&amp; (col.children.length &gt; 1 || leftBorder)
//                     let childRight = i === col.children.length - 1 &amp;&amp; (col.children.length &gt; 1 || rightBorder)
//                     let childSize = this.computeRenderDataRec(cols, child, childPos, depth + 1, result, childLeft, childRight)
//                     childPos += childSize
//                     size += childSize
//                 }
//             } else {
//                 for (let i = depth + 1; i &lt; result.length; i++)
//                     result[i].push({id: colId, span: 1, leftBd: leftBorder, rightBd: rightBorder, empty: true})
//                 size = 1
//             }
//             let left = leftBorder
//             let right = rightBorder
//             if (size &g

// %%
fun truncate(s: String, maxLength: Int = 90) =
    if (s.length <= maxLength) s else s.take(maxLength - 1) + "…"

fun printSentences(component: String, n: Int = 5) = run {
    val sorted = features.sortByDesc(component)
    val top = sorted.take(n)
    val bottom = sorted.takeLast(n)

    fun printRows(rows: AnyFrame) {
        val sentences = rows["sentence"].toList().map { truncate(it.toString()) }
        val values = rows[component].toList().map { (it as Number).toDouble() }
        sentences.zip(values).forEach { (sentence, value) ->
            println("%+.3f  %s".format(value, sentence))
        }
    }

    printRows(top)
    println("...")
    printRows(bottom)
}

// %% [markdown]
// ### Slow feature 1

// %%
printSentences("sf1")
plotLoadings("sf1")
// Out:
// +6.253  Even my eye balls were vibrating.
// +5.955  My ears were twitching, one at a time.
// +5.416  My head has been popping today while resting and listening to some meditation music with …
// +5.402  I could feel little bubbles in my earlobes and in my toes from the breathing.
// +5.337  Everything tingles.
// ...
// -3.055  It is very evidently based on concepts, so it’s not some ultimate beingness, and since pe…
// -3.070  If one organizes one's thoughts that way without being normative about the levels.
// -3.091  The question is: Why am I turning this into a personal thing?
// -3.230  If the intention isn't there, then it isn't.
// -3.276  Delusion, reinforced wrong views, wrong ideas about what kind of practice is fruitful, po…
//             <iframe src='about:blank' style='border:none !important;' width='700' height='1600' srcdoc="&lt;html lang=&quot;en&quot;>
//    &lt;head>
//        &lt;meta charset=&quot;UTF-8&quot;>
//        &lt;style> html, body { margin: 0; padding: 0; overflow: hidden; } &lt;/style>
//        &lt;script type=&quot;text/javascript&quot; data-lets-plot-script=&quot;library&quot; src=&quot;https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.8.2/js-package/distr/lets-plot.min.js&quot;>&lt;/script>
//    &lt;/head>
//    &lt;body>
//           &lt;div id=&quot;Hl4RE7&quot; >&lt;/div>
//    &lt;script type=&quot;text/javascript&quot; data-lets-plot-script=&quot;plot&quot;>
//
//    (function() {
//    // ----------
//
//    const forceImmediateRender = false;
//    const responsive = false;
//
//    let sizing = {
//        width_mode: &quot;FIXED&quot;,
//        height_mode: &quot;FIXED&quot;,
//        width: 700.0,
//        height: 1600.0
//    };
//
//    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
//    if (preferredWidth !== undefined) {
//        sizing = {
//            width_mode: 'FIXED',
//            height_mode: 'SCALED',
//            width: parseFloat(preferredWidth)
//        };
//    }
//
//    const containerDiv = document.getElementById(&quot;Hl4RE7&quot;);
//    let fig = null;
//
//    function renderPlot() {
//        if (fig === null) {
//            const plotSpec = {
// &quot;ggtitle&quot;:{
// &quot;text&quot;:&quot;Label weights in SFA component \&quot;sf1\&quot;&quot;
// },
// &quot;mapping&quot;:{
// },
// &quot;data&quot;:{
// },
// &quot;ggsize&quot;:{
// &quot;width&quot;:700.0,
// &quot;height&quot;:1600.0
// },
// &quot;kind&quot;:&quot;plot&quot;,
// &quot;scales&quot;:[{
// &quot;aesthetic&quot;:&quot;y&quot;,
// &quot;discrete&quot;:true,
// &quot;name&quot;:&quot;label&quot;
// },{
// &quot;aesthetic&quot;:&quot;x&quot;,
// &quot;name&quot;:&quot;loading&quot;,
// &quot;limits&quot;:[null,null]
// },{
// &quot;aesthetic&quot;:&quot;fill&quot;,
// &quot;scale_mapper_kind&quot;:&quot;color_gradient2&quot;,
// &quot;high&quot;:&quot;#ee6666&quot;,
// &quot;low&quot;:&quot;#5470c6&quot;,
// &quot;name&quot;:&quot;loading&quot;,
// &quot;mid&quot;:&quot;#ffffff&quot;,
// &quot;midpoint&quot;:0.0,
// &quot;limits&quot;:[null,null]
// }],
// &quot;layers&quot;:[{
// &quot;mapping&quot;:{
// &quot;y&quot;:&quot;y&quot;,
// &quot;x&quot;:&quot;x&quot;,
// &quot;fill&quot;:&quot;fill&quot;
// },
// &quot;stat&quot;:&quot;identity&quot;,
// &quot;orientation&quot;:&quot;y&quot;,
// &quot;data&quot;:{
// &quot;x&quot;:[-0.3929829404124552,-0.29397104469407365,-0.2594874234396143,-0.23564225671139777,-0.22384489479143088,-0.17246062102787965,-0.16691504187655862,-0.15596681084922687,-0.12973300477702107,-0.11507822251730838,-0.09274651251869129,-0.06502461069661675,-0.06502461069661675,-0.05539996113804361,-0.05393585915475293,-0.040117265420505144,-0.022758121996595937,-0.005827827083323182,-5.951117039162263E-4,0.0011749763667164763,0.0034159210348140845,0.008390405826476544,0.016148683257730778,0.01666606708722456,0.019999922444803808,0.02069914395818878,0.027686111875447166,0.04131215038350522,0.04421385488802426,0.044278008431090345,0.05143013922357445,0.05651415236432619,0.06493044520402366,0.0742919746778274,0.08455569598462587,0.09271375528952376,0.09533581763546356,0.10462714067646442,0.13297021474946127,0.13796022606785407,0.14012962374109159,0.15171767146798393,0.1622626553108175,0.17963388001778796,0.18422903853583295,0.18749691185804107,0.19170508652267754,0.20393487032967872,0.21247112240285781,0.21277049440733112,0.2195271489055628,0.21987086934011682,0.22192621496177933,0.2387971608395085,0.27651663017770295,0.3053763147812627,0.3157011352469754,0.32043177631943265,0.34293239027475675,0.3516032051098624,0.35423868962595684,0.35511018051061305,0.356873442536002,0.36565843201378456,0.4120300889699815,0.5082681344558925,0.6812373422621273,0.9354295269392232,1.0179772900309143,1.3642261431488962],
// &quot;y&quot;:[&quot;conceptual&quot;,&quot;sense of agency&quot;,&quot;self-judgment&quot;,&quot;self-criticism&quot;,&quot;abstract&quot;,&quot;equanimity wrt negative&quot;,&quot;subjective&quot;,&quot;being challenged&quot;,&quot;mental&quot;,&quot;equanimity wrt opposites&quot;,&quot;dissonance&quot;,&quot;passivity&quot;,&quot;passivity&quot;,&quot;objective&quot;,&quot;self-image&quot;,&quot;self-esteem&quot;,&quot;equanimity&quot;,&quot;dullness&quot;,&quot;weak sense of self&quot;,&quot;turtles&quot;,&quot;self-referential&quot;,&quot;focus&quot;,&quot;paradox&quot;,&quot;self-consciousness&quot;,&quot;self-acceptance&quot;,&quot;struggling&quot;,&quot;metaphorical&quot;,&quot;author referring to themselves&quot;,&quot;self-compassion&quot;,&quot;pain&quot;,&quot;sleepiness&quot;,&quot;confusion&quot;,&quot;polarities&quot;,&quot;concentration&quot;,&quot;measurable&quot;,&quot;high concentration&quot;,&quot;opposites&quot;,&quot;phenomena that change over hours&quot;,&quot;auditory&quot;,&quot;satisfaction&quot;,&quot;calmness&quot;,&quot;self-awareness&quot;,&quot;harmony&quot;,&quot;self-reference&quot;,&quot;self-reflection&quot;,&quot;tingling&quot;,&quot;happiness&quot;,&quot;sounds&quot;,&quot;alertness&quot;,&quot;dualities&quot;,&quot;vague&quot;,&quot;vibrations&quot;,&quot;phenomena that change over minutes&quot;,&quot;lack of agency&quot;,&quot;mental images&quot;,&quot;visual&quot;,&quot;awareness&quot;,&quot;mystical experience&quot;,&quot;phenomena that change over seconds&quot;,&quot;self-perception&quot;,&quot;non-conceptual&quot;,&quot;specific&quot;,&quot;weird&quot;,&quot;energetic&quot;,&quot;attention&quot;,&quot;low concentration&quot;,&quot;body&quot;,&quot;somatic&quot;,&quot;direct experience&quot;,&quot;sensory&quot;],
// &quot;fill&quot;:[-0.3929829404124552,-0.29397104469407365,-0.2594874234396143,-0.23564225671139777,-0.22384489479143088,-0.17246062102787965,-0.16691504187655862,-0.15596681084922687,-0.12973300477702107,-0.11507822251730838,-0.09274651251869129,-0.06502461069661675,-0.06502461069661675,-0.05539996113804361,-0.05393585915475293,-0.040117265420505144,-0.022758121996595937,-0.005827827083323182,-5.951117039162263E-4,0.0011749763667164763,0.0034159210348140845,0.008390405826476544,0.016148683257730778,0.01666606708722456,0.019999922444803808,0.02069914395818878,0.027686111875447166,0.04131215038350522,0.04421385488802426,0.044278008431090345,0.05143013922357445,0.05651415236432619,0.06493044520402366,0.0742919746778274,0.08455569598462587,0.09271375528952376,0.09533581763546356,0.10462714067646442,0.13297021474946127,0.13796022606785407,0.14012962374109159,0.15171767146798393,0.1622626553108175,0.17963388001778796,0.18422903853583295,0.18749691185804107,0.19170508652267754,0.20393487032967872,0.21247112240285781,0.21277049440733112,0.2195271489055628,0.21987086934011682,0.22192621496177933,0.2387971608395085,0.27651663017770295,0.3053763147812627,0.3157011352469754,0.32043177631943265,0.34293239027475675,0.3516032051098624,0.35423868962595684,0.35511018051061305,0.356873442536002,0.36565843201378456,0.4120300889699815,0.5082681344558925,0.6812373422621273,0.9354295269392232,1.0179772900309143,1.3642261431488962]
// },
// &quot;sampling&quot;:&quot;none&quot;,
// &quot;inherit_aes&quot;:false,
// &quot;position&quot;:&quot;dodge&quot;,
// &quot;geom&quot;:&quot;bar&quot;,
// &quot;data_meta&quot;:{
// &quot;series_annotations&quot;:[{
// &quot;type&quot;:&quot;str&quot;,
// &quot;column&quot;:&quot;y&quot;
// },{
// &quot;type&quot;:&quot;float&quot;,
// &quot;column&quot;:&quot;x&quot;
// },{
// &quot;type&quot;:&quot;float&quot;,
// &quot;column&quot;:&quot;fill&quot;
// }]
// }
// }],
// &quot;spec_id&quot;:&quot;2&quot;
// };
//            fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, containerDiv, sizing);
//        } else {
//            fig.updateView({});
//        }
//    }
//
//    const renderImmediately =
//        forceImmediateRender || (
//            sizing.width_mode === 'FIXED' &amp;&amp;
//            (sizing.height_mode === 'FIXED' || sizing.height_mode === 'SCALED')
//        );
//
//    if (renderImmediately) {
//        renderPlot();
//    }
//
//    if (!renderImmediately || responsive) {
//        // Set up observer fo

// %% [markdown]
// ### Slow feature 2

// %%
printSentences("sf2")
plotLoadings("sf2")
// Out:
// +6.302  There were flickerings, waves and vortexes where there "should" be bathroom walls and con…
// +5.982  Also, many (?)
// +5.909  It was all vibrations or static noise, maybe ones and zeroes popping up and disappearing.
// +5.904  Utter confusion.
// +5.740  Totally unrelated to that, there was also some dreamlike scene or dreamy thought (?) that…
// ...
// -6.580  I have been equanimous and pretty efficient and content and managed to do more than I had…
// -6.610  This morning I woke up at 5:30 with a strong need to go up and meditate, and it felt grea…
// -6.710  I did it slowly and mindfully, especially the prostrations.
// -6.715  Peace in seeing through those impulses noted.
// -6.954  I got there doing metta on myself, focusing on making all the different me:s feel safe an…
//             <iframe src='about:blank' style='border:none !important;' width='700' height='1600' srcdoc="&lt;html lang=&quot;en&quot;>
//    &lt;head>
//        &lt;meta charset=&quot;UTF-8&quot;>
//        &lt;style> html, body { margin: 0; padding: 0; overflow: hidden; } &lt;/style>
//        &lt;script type=&quot;text/javascript&quot; data-lets-plot-script=&quot;library&quot; src=&quot;https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.8.2/js-package/distr/lets-plot.min.js&quot;>&lt;/script>
//    &lt;/head>
//    &lt;body>
//           &lt;div id=&quot;U9JlAr&quot; >&lt;/div>
//    &lt;script type=&quot;text/javascript&quot; data-lets-plot-script=&quot;plot&quot;>
//
//    (function() {
//    // ----------
//
//    const forceImmediateRender = false;
//    const responsive = false;
//
//    let sizing = {
//        width_mode: &quot;FIXED&quot;,
//        height_mode: &quot;FIXED&quot;,
//        width: 700.0,
//        height: 1600.0
//    };
//
//    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
//    if (preferredWidth !== undefined) {
//        sizing = {
//            width_mode: 'FIXED',
//            height_mode: 'SCALED',
//            width: parseFloat(preferredWidth)
//        };
//    }
//
//    const containerDiv = document.getElementById(&quot;U9JlAr&quot;);
//    let fig = null;
//
//    function renderPlot() {
//        if (fig === null) {
//            const plotSpec = {
// &quot;ggtitle&quot;:{
// &quot;text&quot;:&quot;Label weights in SFA component \&quot;sf2\&quot;&quot;
// },
// &quot;mapping&quot;:{
// },
// &quot;data&quot;:{
// },
// &quot;ggsize&quot;:{
// &quot;width&quot;:700.0,
// &quot;height&quot;:1600.0
// },
// &quot;kind&quot;:&quot;plot&quot;,
// &quot;scales&quot;:[{
// &quot;aesthetic&quot;:&quot;y&quot;,
// &quot;discrete&quot;:true,
// &quot;name&quot;:&quot;label&quot;
// },{
// &quot;aesthetic&quot;:&quot;x&quot;,
// &quot;name&quot;:&quot;loading&quot;,
// &quot;limits&quot;:[null,null]
// },{
// &quot;aesthetic&quot;:&quot;fill&quot;,
// &quot;scale_mapper_kind&quot;:&quot;color_gradient2&quot;,
// &quot;high&quot;:&quot;#ee6666&quot;,
// &quot;low&quot;:&quot;#5470c6&quot;,
// &quot;name&quot;:&quot;loading&quot;,
// &quot;mid&quot;:&quot;#ffffff&quot;,
// &quot;midpoint&quot;:0.0,
// &quot;limits&quot;:[null,null]
// }],
// &quot;layers&quot;:[{
// &quot;mapping&quot;:{
// &quot;y&quot;:&quot;y&quot;,
// &quot;x&quot;:&quot;x&quot;,
// &quot;fill&quot;:&quot;fill&quot;
// },
// &quot;stat&quot;:&quot;identity&quot;,
// &quot;orientation&quot;:&quot;y&quot;,
// &quot;data&quot;:{
// &quot;x&quot;:[-0.8347325307308593,-0.6994486135559868,-0.6338701678540415,-0.5526886691670957,-0.49123452823381397,-0.4838542639120591,-0.47267978341301253,-0.460978420470675,-0.4554299100757312,-0.4312977069731584,-0.4174868262712616,-0.3229145090279119,-0.31700950920542686,-0.30336296201825985,-0.2916149557777391,-0.28205876419582565,-0.2761284617691694,-0.253184024865766,-0.24214506864457977,-0.24214506864457974,-0.2236075180224692,-0.22240307096474743,-0.18545511330593661,-0.16242303582871503,-0.12179802852134883,-0.10107500389092829,-0.0852398955419425,-0.08328231286757741,-0.058329422283234234,-0.03882692663719474,-0.03833287030121518,-0.03603474896460537,-0.030295601215197976,-0.028294808425980755,-0.012704767363436703,-9.277530976149889E-4,8.243777339907365E-4,0.008998019323812056,0.02367533063705779,0.04056148892879813,0.046239573930089206,0.048171544924504386,0.06289708106578383,0.066245025689042,0.10753007590595832,0.14361220703407696,0.15145146291288586,0.15948531500562935,0.1663678409790401,0.17528201858656042,0.18608487523012052,0.1938677780726289,0.20514270965213383,0.23197848758541328,0.24094980865633986,0.26435519029859883,0.2816855948867601,0.2893998664879464,0.32217400399239754,0.3303717601037443,0.3385480082261988,0.3624889068192212,0.36731142241614223,0.5081163558638604,0.5242952656344557,0.6772590706285195,0.9061549235153776,0.9221043743243649,0.9767830044253757,0.9994950956085911],
// &quot;y&quot;:[&quot;calmness&quot;,&quot;equanimity&quot;,&quot;sense of agency&quot;,&quot;satisfaction&quot;,&quot;focus&quot;,&quot;self-reference&quot;,&quot;harmony&quot;,&quot;high concentration&quot;,&quot;concentration&quot;,&quot;awareness&quot;,&quot;specific&quot;,&quot;self-acceptance&quot;,&quot;happiness&quot;,&quot;self-reflection&quot;,&quot;self-awareness&quot;,&quot;self-referential&quot;,&quot;self-perception&quot;,&quot;direct experience&quot;,&quot;passivity&quot;,&quot;passivity&quot;,&quot;self-compassion&quot;,&quot;author referring to themselves&quot;,&quot;measurable&quot;,&quot;alertness&quot;,&quot;objective&quot;,&quot;equanimity wrt opposites&quot;,&quot;conceptual&quot;,&quot;sounds&quot;,&quot;phenomena that change over hours&quot;,&quot;self-esteem&quot;,&quot;self-image&quot;,&quot;dullness&quot;,&quot;mental&quot;,&quot;somatic&quot;,&quot;energetic&quot;,&quot;phenomena that change over minutes&quot;,&quot;turtles&quot;,&quot;body&quot;,&quot;metaphorical&quot;,&quot;attention&quot;,&quot;tingling&quot;,&quot;vibrations&quot;,&quot;self-consciousness&quot;,&quot;sleepiness&quot;,&quot;abstract&quot;,&quot;self-judgment&quot;,&quot;equanimity wrt negative&quot;,&quot;phenomena that change over seconds&quot;,&quot;mystical experience&quot;,&quot;polarities&quot;,&quot;visual&quot;,&quot;mental images&quot;,&quot;paradox&quot;,&quot;auditory&quot;,&quot;pain&quot;,&quot;subjective&quot;,&quot;being challenged&quot;,&quot;weak sense of self&quot;,&quot;opposites&quot;,&quot;non-conceptual&quot;,&quot;dualities&quot;,&quot;sensory&quot;,&quot;self-criticism&quot;,&quot;weird&quot;,&quot;vague&quot;,&quot;confusion&quot;,&quot;dissonance&quot;,&quot;low concentration&quot;,&quot;struggling&quot;,&quot;lack of agency&quot;],
// &quot;fill&quot;:[-0.8347325307308593,-0.6994486135559868,-0.6338701678540415,-0.5526886691670957,-0.49123452823381397,-0.4838542639120591,-0.47267978341301253,-0.460978420470675,-0.4554299100757312,-0.4312977069731584,-0.4174868262712616,-0.3229145090279119,-0.31700950920542686,-0.30336296201825985,-0.2916149557777391,-0.28205876419582565,-0.2761284617691694,-0.253184024865766,-0.24214506864457977,-0.24214506864457974,-0.2236075180224692,-0.22240307096474743,-0.18545511330593661,-0.16242303582871503,-0.12179802852134883,-0.10107500389092829,-0.0852398955419425,-0.08328231286757741,-0.058329422283234234,-0.03882692663719474,-0.03833287030121518,-0.03603474896460537,-0.030295601215197976,-0.028294808425980755,-0.012704767363436703,-9.277530976149889E-4,8.243777339907365E-4,0.008998019323812056,0.02367533063705779,0.04056148892879813,0.046239573930089206,0.048171544924504386,0.06289708106578383,0.066245025689042,0.10753007590595832,0.14361220703407696,0.15145146291288586,0.15948531500562935,0.1663678409790401,0.17528201858656042,0.18608487523012052,0.1938677780726289,0.20514270965213383,0.23197848758541328,0.24094980865633986,0.26435519029859883,0.2816855948867601,0.2893998664879464,0.32217400399239754,0.3303717601037443,0.3385480082261988,0.3624889068192212,0.36731142241614223,0.5081163558638604,0.5242952656344557,0.6772590706285195,0.9061549235153776,0.9221043743243649,0.9767830044253757,0.9994950956085911]
// },
// &quot;sampling&quot;:&quot;none&quot;,
// &quot;inherit_aes&quot;:false,
// &quot;position&quot;:&quot;dodge&quot;,
// &quot;geom&quot;:&quot;bar&quot;,
// &quot;data_meta&quot;:{
// &quot;series_annotations&quot;:[{
// &quot;type&quot;:&quot;str&quot;,
// &quot;column&quot;:&quot;y&quot;
// },{
// &quot;type&quot;:&quot;float&quot;,
// &quot;column&quot;:&quot;x&quot;
// },{
// &quot;type&quot;:&quot;float&quot;,
// &quot;column&quot;:&quot;fill&quot;
// }]
// }
// }],
// &quot;spec_id&quot;:&quot;5&quot;
// };
//            fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, containerDiv, sizing);
//        } else {
//            fig.updateView({});
//        }
//    }
//
//    const renderImmediately =
//        forceImmediateRender || (
//            sizing.width_mode === 'FIXED' &amp;&amp;
//            (sizing.height_mode === 'FIXED' || sizing.height_mode === 'SCALED')
//        );
//
//    if (renderImmediately) {
//        renderPlot();
//    }
//
//    if (!renderImmediately || responsive) {
//        // Set up observer for init

// %% [markdown]
// ### Slow feature 3

// %%
printSentences("sf3")
plotLoadings("sf3")
// Out:
// +6.204  Embarrassingly enough, I have basically been trying to get rid of space.
// +6.170  I failed at my attempt to do just sitting for 30 minutes today.
// +6.146  I should have slept instead.
// +6.055  And most of my life I have really not taken care of it.
// +6.047  I'm a chronic procrastinator with enormous performance anxiety.
// ...
// -4.921  Like pathways opening up, something melting (liquid-ish), expansions and contractions.
// -5.074  Then a strong energetic surge, like a wave of bliss, accompanied by a psychedelic light s…
// -5.121  There was a slow surging wavelike movement of attention between the left and the right si…
// -5.140  Not luminous jhana, but there was light swirling around and sometimes concentrating itsel…
// -5.261  There was like a giant pressure wave that made everything sort of shift around and then, …
//             <iframe src='about:blank' style='border:none !important;' width='700' height='1600' srcdoc="&lt;html lang=&quot;en&quot;>
//    &lt;head>
//        &lt;meta charset=&quot;UTF-8&quot;>
//        &lt;style> html, body { margin: 0; padding: 0; overflow: hidden; } &lt;/style>
//        &lt;script type=&quot;text/javascript&quot; data-lets-plot-script=&quot;library&quot; src=&quot;https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.8.2/js-package/distr/lets-plot.min.js&quot;>&lt;/script>
//    &lt;/head>
//    &lt;body>
//           &lt;div id=&quot;S0mD4s&quot; >&lt;/div>
//    &lt;script type=&quot;text/javascript&quot; data-lets-plot-script=&quot;plot&quot;>
//
//    (function() {
//    // ----------
//
//    const forceImmediateRender = false;
//    const responsive = false;
//
//    let sizing = {
//        width_mode: &quot;FIXED&quot;,
//        height_mode: &quot;FIXED&quot;,
//        width: 700.0,
//        height: 1600.0
//    };
//
//    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
//    if (preferredWidth !== undefined) {
//        sizing = {
//            width_mode: 'FIXED',
//            height_mode: 'SCALED',
//            width: parseFloat(preferredWidth)
//        };
//    }
//
//    const containerDiv = document.getElementById(&quot;S0mD4s&quot;);
//    let fig = null;
//
//    function renderPlot() {
//        if (fig === null) {
//            const plotSpec = {
// &quot;ggtitle&quot;:{
// &quot;text&quot;:&quot;Label weights in SFA component \&quot;sf3\&quot;&quot;
// },
// &quot;mapping&quot;:{
// },
// &quot;data&quot;:{
// },
// &quot;ggsize&quot;:{
// &quot;width&quot;:700.0,
// &quot;height&quot;:1600.0
// },
// &quot;kind&quot;:&quot;plot&quot;,
// &quot;scales&quot;:[{
// &quot;aesthetic&quot;:&quot;y&quot;,
// &quot;discrete&quot;:true,
// &quot;name&quot;:&quot;label&quot;
// },{
// &quot;aesthetic&quot;:&quot;x&quot;,
// &quot;name&quot;:&quot;loading&quot;,
// &quot;limits&quot;:[null,null]
// },{
// &quot;aesthetic&quot;:&quot;fill&quot;,
// &quot;scale_mapper_kind&quot;:&quot;color_gradient2&quot;,
// &quot;high&quot;:&quot;#ee6666&quot;,
// &quot;low&quot;:&quot;#5470c6&quot;,
// &quot;name&quot;:&quot;loading&quot;,
// &quot;mid&quot;:&quot;#ffffff&quot;,
// &quot;midpoint&quot;:0.0,
// &quot;limits&quot;:[null,null]
// }],
// &quot;layers&quot;:[{
// &quot;mapping&quot;:{
// &quot;y&quot;:&quot;y&quot;,
// &quot;x&quot;:&quot;x&quot;,
// &quot;fill&quot;:&quot;fill&quot;
// },
// &quot;stat&quot;:&quot;identity&quot;,
// &quot;orientation&quot;:&quot;y&quot;,
// &quot;data&quot;:{
// &quot;x&quot;:[-0.7208978988474359,-0.6871986540765491,-0.6418396843609792,-0.6246640958810569,-0.5427051626629744,-0.3188641998613123,-0.314601556153915,-0.3131997919942684,-0.30392946515935687,-0.3036566056812705,-0.28174540846174595,-0.2787672417639832,-0.2616627442495675,-0.24001698125502519,-0.23389004691729257,-0.23276796128838068,-0.2028412770993151,-0.1982885944712012,-0.19130317436359218,-0.18480547491220853,-0.17782400479932828,-0.17707957113700956,-0.17251096461243434,-0.17168790767207834,-0.14894812089815698,-0.14258003456741905,-0.14123233868120988,-0.14030470421979113,-0.139628477377095,-0.10604570808561864,-0.10481780657488197,-0.09549403301325328,-0.09230279174139613,-0.09090390716450142,-0.031246023176886698,-0.02209489618015717,-0.02206528558980178,-0.018709030487720338,-8.299410409105725E-4,0.03155430936872786,0.03788114351587238,0.045722645970917256,0.06775914690777599,0.07428203325557797,0.10297468366311824,0.10311172369096819,0.11357955005763926,0.13031504994699486,0.13338710349852742,0.1581970425794024,0.1974197544638474,0.23386113090199664,0.23639491437780202,0.26094453798517236,0.2866150982728469,0.31550106574957876,0.34458037510483475,0.34458037510483475,0.3560650717097883,0.3857767293301405,0.3953813333559515,0.46251159344854537,0.47819431259255524,0.5070402079891977,0.5695653299463189,0.5791046089698287,0.589149824040869,0.7198290313661553,0.7268860054064977,0.7836823496984638],
// &quot;y&quot;:[&quot;sensory&quot;,&quot;conceptual&quot;,&quot;abstract&quot;,&quot;metaphorical&quot;,&quot;mystical experience&quot;,&quot;energetic&quot;,&quot;visual&quot;,&quot;vague&quot;,&quot;harmony&quot;,&quot;mental images&quot;,&quot;high concentration&quot;,&quot;attention&quot;,&quot;calmness&quot;,&quot;awareness&quot;,&quot;sounds&quot;,&quot;equanimity&quot;,&quot;weird&quot;,&quot;satisfaction&quot;,&quot;focus&quot;,&quot;vibrations&quot;,&quot;happiness&quot;,&quot;dualities&quot;,&quot;concentration&quot;,&quot;tingling&quot;,&quot;alertness&quot;,&quot;phenomena that change over seconds&quot;,&quot;subjective&quot;,&quot;paradox&quot;,&quot;mental&quot;,&quot;equanimity wrt opposites&quot;,&quot;opposites&quot;,&quot;confusion&quot;,&quot;objective&quot;,&quot;polarities&quot;,&quot;phenomena that change over minutes&quot;,&quot;self-acceptance&quot;,&quot;somatic&quot;,&quot;auditory&quot;,&quot;turtles&quot;,&quot;measurable&quot;,&quot;body&quot;,&quot;non-conceptual&quot;,&quot;self-compassion&quot;,&quot;self-esteem&quot;,&quot;sleepiness&quot;,&quot;phenomena that change over hours&quot;,&quot;specific&quot;,&quot;being challenged&quot;,&quot;self-consciousness&quot;,&quot;self-image&quot;,&quot;dullness&quot;,&quot;direct experience&quot;,&quot;pain&quot;,&quot;weak sense of self&quot;,&quot;low concentration&quot;,&quot;dissonance&quot;,&quot;passivity&quot;,&quot;passivity&quot;,&quot;lack of agency&quot;,&quot;equanimity wrt negative&quot;,&quot;sense of agency&quot;,&quot;self-referential&quot;,&quot;self-judgment&quot;,&quot;self-perception&quot;,&quot;author referring to themselves&quot;,&quot;struggling&quot;,&quot;self-awareness&quot;,&quot;self-reference&quot;,&quot;self-reflection&quot;,&quot;self-criticism&quot;],
// &quot;fill&quot;:[-0.7208978988474359,-0.6871986540765491,-0.6418396843609792,-0.6246640958810569,-0.5427051626629744,-0.3188641998613123,-0.314601556153915,-0.3131997919942684,-0.30392946515935687,-0.3036566056812705,-0.28174540846174595,-0.2787672417639832,-0.2616627442495675,-0.24001698125502519,-0.23389004691729257,-0.23276796128838068,-0.2028412770993151,-0.1982885944712012,-0.19130317436359218,-0.18480547491220853,-0.17782400479932828,-0.17707957113700956,-0.17251096461243434,-0.17168790767207834,-0.14894812089815698,-0.14258003456741905,-0.14123233868120988,-0.14030470421979113,-0.139628477377095,-0.10604570808561864,-0.10481780657488197,-0.09549403301325328,-0.09230279174139613,-0.09090390716450142,-0.031246023176886698,-0.02209489618015717,-0.02206528558980178,-0.018709030487720338,-8.299410409105725E-4,0.03155430936872786,0.03788114351587238,0.045722645970917256,0.06775914690777599,0.07428203325557797,0.10297468366311824,0.10311172369096819,0.11357955005763926,0.13031504994699486,0.13338710349852742,0.1581970425794024,0.1974197544638474,0.23386113090199664,0.23639491437780202,0.26094453798517236,0.2866150982728469,0.31550106574957876,0.34458037510483475,0.34458037510483475,0.3560650717097883,0.3857767293301405,0.3953813333559515,0.46251159344854537,0.47819431259255524,0.5070402079891977,0.5695653299463189,0.5791046089698287,0.589149824040869,0.7198290313661553,0.7268860054064977,0.7836823496984638]
// },
// &quot;sampling&quot;:&quot;none&quot;,
// &quot;inherit_aes&quot;:false,
// &quot;position&quot;:&quot;dodge&quot;,
// &quot;geom&quot;:&quot;bar&quot;,
// &quot;data_meta&quot;:{
// &quot;series_annotations&quot;:[{
// &quot;type&quot;:&quot;str&quot;,
// &quot;column&quot;:&quot;y&quot;
// },{
// &quot;type&quot;:&quot;float&quot;,
// &quot;column&quot;:&quot;x&quot;
// },{
// &quot;type&quot;:&quot;float&quot;,
// &quot;column&quot;:&quot;fill&quot;
// }]
// }
// }],
// &quot;spec_id&quot;:&quot;8&quot;
// };
//            fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, containerDiv, sizing);
//        } else {
//            fig.updateView({});
//        }
//    }
//
//    const renderImmediately =
//        forceImmediateRender || (
//            sizing.width_mode === 'FIXED' &amp;&amp;
//            (sizing.height_mode === 'FIXED' || sizing.height_mode === 'SCALED')
//        );
//
//    if (renderImmediately) {
//        renderPlot();
//    }
//
//    if (!renderImmediately || responsive) {
//        // Set up observer for in

// %% [markdown]
// ### Slow feature 4

// %%
printSentences("sf4")
plotLoadings("sf4")
// Out:
// +7.796  Peaceful, nothing special.
// +7.308  Nothing spectacular, just peace.
// +6.984  Generally equanimous.
// +6.979  It was close to pure peace, so not much to report.
// +6.890  Meh...
// ...
// -4.501  Focusing on my finger tips so much seems to have caused a heightened awareness of my puls…
// -4.553  In the afternoon I did Vinyasa yoga at the yoga studio and now I feel distinctly more ale…
// -4.594  When the body wasn't gone, it was there very intensely just like in third vipassana jhana…
// -4.723  Oh, I forgot to write that I noticed the deluded ”self” moving around in my body very tan…
// -4.914  Earlier that day, while walking through heavy snow to the hospital, I caught myself being…
//             <iframe src='about:blank' style='border:none !important;' width='700' height='1600' srcdoc="&lt;html lang=&quot;en&quot;>
//    &lt;head>
//        &lt;meta charset=&quot;UTF-8&quot;>
//        &lt;style> html, body { margin: 0; padding: 0; overflow: hidden; } &lt;/style>
//        &lt;script type=&quot;text/javascript&quot; data-lets-plot-script=&quot;library&quot; src=&quot;https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.8.2/js-package/distr/lets-plot.min.js&quot;>&lt;/script>
//    &lt;/head>
//    &lt;body>
//           &lt;div id=&quot;v9BZbJ&quot; >&lt;/div>
//    &lt;script type=&quot;text/javascript&quot; data-lets-plot-script=&quot;plot&quot;>
//
//    (function() {
//    // ----------
//
//    const forceImmediateRender = false;
//    const responsive = false;
//
//    let sizing = {
//        width_mode: &quot;FIXED&quot;,
//        height_mode: &quot;FIXED&quot;,
//        width: 700.0,
//        height: 1600.0
//    };
//
//    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
//    if (preferredWidth !== undefined) {
//        sizing = {
//            width_mode: 'FIXED',
//            height_mode: 'SCALED',
//            width: parseFloat(preferredWidth)
//        };
//    }
//
//    const containerDiv = document.getElementById(&quot;v9BZbJ&quot;);
//    let fig = null;
//
//    function renderPlot() {
//        if (fig === null) {
//            const plotSpec = {
// &quot;ggtitle&quot;:{
// &quot;text&quot;:&quot;Label weights in SFA component \&quot;sf4\&quot;&quot;
// },
// &quot;mapping&quot;:{
// },
// &quot;data&quot;:{
// },
// &quot;ggsize&quot;:{
// &quot;width&quot;:700.0,
// &quot;height&quot;:1600.0
// },
// &quot;kind&quot;:&quot;plot&quot;,
// &quot;scales&quot;:[{
// &quot;aesthetic&quot;:&quot;y&quot;,
// &quot;discrete&quot;:true,
// &quot;name&quot;:&quot;label&quot;
// },{
// &quot;aesthetic&quot;:&quot;x&quot;,
// &quot;name&quot;:&quot;loading&quot;,
// &quot;limits&quot;:[null,null]
// },{
// &quot;aesthetic&quot;:&quot;fill&quot;,
// &quot;scale_mapper_kind&quot;:&quot;color_gradient2&quot;,
// &quot;high&quot;:&quot;#ee6666&quot;,
// &quot;low&quot;:&quot;#5470c6&quot;,
// &quot;name&quot;:&quot;loading&quot;,
// &quot;mid&quot;:&quot;#ffffff&quot;,
// &quot;midpoint&quot;:0.0,
// &quot;limits&quot;:[null,null]
// }],
// &quot;layers&quot;:[{
// &quot;mapping&quot;:{
// &quot;y&quot;:&quot;y&quot;,
// &quot;x&quot;:&quot;x&quot;,
// &quot;fill&quot;:&quot;fill&quot;
// },
// &quot;stat&quot;:&quot;identity&quot;,
// &quot;orientation&quot;:&quot;y&quot;,
// &quot;data&quot;:{
// &quot;x&quot;:[-0.7943777393648048,-0.39570961742582594,-0.35661896544453237,-0.2957749937812797,-0.278012755156356,-0.2647702893342152,-0.24768438980614682,-0.24115902043921242,-0.22604419232283757,-0.20438274627560304,-0.18941023443890864,-0.18830601981275116,-0.1621870408421811,-0.15537322977696177,-0.15202900134907116,-0.15179914276424963,-0.13746103405897397,-0.13626599585080568,-0.12616762020417477,-0.12128127244227464,-0.11229083642411246,-0.11186012031165987,-0.10630315216090383,-0.10143731849805616,-0.0983459763101654,-0.09640115798278386,-0.09502052775361557,-0.08657727467290363,-0.08252676399231897,-0.07180041138737281,-0.0692696525122811,-0.06915123991650327,-0.06706406773366352,-0.053679542508664205,-0.04835869340234736,-0.04708115243122113,-0.0281697692903483,-0.022063291007997924,1.7710871908260866E-4,0.0012274915869722805,0.0059838708667893925,0.007369697818505126,0.01252409896955976,0.04577759244842378,0.05308732293362837,0.06423790662957457,0.0714654919771443,0.08475735466688551,0.087372634244814,0.09368955841206979,0.1499661192611359,0.16250797666948805,0.1773293773835009,0.2248432086896069,0.2509394041973579,0.2549046732164498,0.2616626430548257,0.2737179228979585,0.3560429979578686,0.3711112574789194,0.39085203261336965,0.4435941176327296,0.5693129211459826,0.7739718801211515,0.792049496815935,0.8037269108150727,0.887875648132969,0.9138943581989516,1.1437214292288067,1.1437214292288067],
// &quot;y&quot;:[&quot;specific&quot;,&quot;self-referential&quot;,&quot;dualities&quot;,&quot;attention&quot;,&quot;high concentration&quot;,&quot;direct experience&quot;,&quot;body&quot;,&quot;self-reference&quot;,&quot;energetic&quot;,&quot;sensory&quot;,&quot;weird&quot;,&quot;self-criticism&quot;,&quot;author referring to themselves&quot;,&quot;pain&quot;,&quot;mental&quot;,&quot;somatic&quot;,&quot;alertness&quot;,&quot;visual&quot;,&quot;opposites&quot;,&quot;being challenged&quot;,&quot;measurable&quot;,&quot;mental images&quot;,&quot;self-perception&quot;,&quot;phenomena that change over seconds&quot;,&quot;self-reflection&quot;,&quot;paradox&quot;,&quot;polarities&quot;,&quot;struggling&quot;,&quot;self-judgment&quot;,&quot;self-consciousness&quot;,&quot;dissonance&quot;,&quot;focus&quot;,&quot;self-awareness&quot;,&quot;vibrations&quot;,&quot;tingling&quot;,&quot;awareness&quot;,&quot;concentration&quot;,&quot;self-image&quot;,&quot;turtles&quot;,&quot;confusion&quot;,&quot;mystical experience&quot;,&quot;phenomena that change over minutes&quot;,&quot;self-esteem&quot;,&quot;sense of agency&quot;,&quot;weak sense of self&quot;,&quot;phenomena that change over hours&quot;,&quot;metaphorical&quot;,&quot;sleepiness&quot;,&quot;subjective&quot;,&quot;conceptual&quot;,&quot;abstract&quot;,&quot;sounds&quot;,&quot;self-compassion&quot;,&quot;equanimity wrt opposites&quot;,&quot;self-acceptance&quot;,&quot;happiness&quot;,&quot;auditory&quot;,&quot;objective&quot;,&quot;harmony&quot;,&quot;satisfaction&quot;,&quot;dullness&quot;,&quot;equanimity wrt negative&quot;,&quot;lack of agency&quot;,&quot;low concentration&quot;,&quot;non-conceptual&quot;,&quot;vague&quot;,&quot;calmness&quot;,&quot;equanimity&quot;,&quot;passivity&quot;,&quot;passivity&quot;],
// &quot;fill&quot;:[-0.7943777393648048,-0.39570961742582594,-0.35661896544453237,-0.2957749937812797,-0.278012755156356,-0.2647702893342152,-0.24768438980614682,-0.24115902043921242,-0.22604419232283757,-0.20438274627560304,-0.18941023443890864,-0.18830601981275116,-0.1621870408421811,-0.15537322977696177,-0.15202900134907116,-0.15179914276424963,-0.13746103405897397,-0.13626599585080568,-0.12616762020417477,-0.12128127244227464,-0.11229083642411246,-0.11186012031165987,-0.10630315216090383,-0.10143731849805616,-0.0983459763101654,-0.09640115798278386,-0.09502052775361557,-0.08657727467290363,-0.08252676399231897,-0.07180041138737281,-0.0692696525122811,-0.06915123991650327,-0.06706406773366352,-0.053679542508664205,-0.04835869340234736,-0.04708115243122113,-0.0281697692903483,-0.022063291007997924,1.7710871908260866E-4,0.0012274915869722805,0.0059838708667893925,0.007369697818505126,0.01252409896955976,0.04577759244842378,0.05308732293362837,0.06423790662957457,0.0714654919771443,0.08475735466688551,0.087372634244814,0.09368955841206979,0.1499661192611359,0.16250797666948805,0.1773293773835009,0.2248432086896069,0.2509394041973579,0.2549046732164498,0.2616626430548257,0.2737179228979585,0.3560429979578686,0.3711112574789194,0.39085203261336965,0.4435941176327296,0.5693129211459826,0.7739718801211515,0.792049496815935,0.8037269108150727,0.887875648132969,0.9138943581989516,1.1437214292288067,1.1437214292288067]
// },
// &quot;sampling&quot;:&quot;none&quot;,
// &quot;inherit_aes&quot;:false,
// &quot;position&quot;:&quot;dodge&quot;,
// &quot;geom&quot;:&quot;bar&quot;,
// &quot;data_meta&quot;:{
// &quot;series_annotations&quot;:[{
// &quot;type&quot;:&quot;str&quot;,
// &quot;column&quot;:&quot;y&quot;
// },{
// &quot;type&quot;:&quot;float&quot;,
// &quot;column&quot;:&quot;x&quot;
// },{
// &quot;type&quot;:&quot;float&quot;,
// &quot;column&quot;:&quot;fill&quot;
// }]
// }
// }],
// &quot;spec_id&quot;:&quot;11&quot;
// };
//            fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, containerDiv, sizing);
//        } else {
//            fig.updateView({});
//        }
//    }
//
//    const renderImmediately =
//        forceImmediateRender || (
//            sizing.width_mode === 'FIXED' &amp;&amp;
//            (sizing.height_mode === 'FIXED' || sizing.height_mode === 'SCALED')
//        );
//
//    if (renderImmediately) {
//        renderPlot();
//    }
//
//    if (!renderImmediately || responsive) {
//        // Set up observer f

// %% [markdown]
// ### Slow feature 5

// %%
printSentences("sf5")
plotLoadings("sf5")
// Out:
// +6.346  Mind recognizing itself.
// +5.977  When I tuned into that space or presence that is consciousness being aware of itself (at …
// +5.971  Now it seems that I need to focus on not focusing on anything, which is paradoxical.
// +5.777  Am I that concentrated on the experience of not being concentrated, or have I completely …
// +5.760  Consciousness recognizing itself.
// ...
// -4.130  The seed was the size of a bean.
// -4.158  That just happened immediately.
// -4.218  After 25 minutes the door bell rang.
// -4.287  It's literally there!
// -4.324  This kept happening over and over again, for hours.
//             <iframe src='about:blank' style='border:none !important;' width='700' height='1600' srcdoc="&lt;html lang=&quot;en&quot;>
//    &lt;head>
//        &lt;meta charset=&quot;UTF-8&quot;>
//        &lt;style> html, body { margin: 0; padding: 0; overflow: hidden; } &lt;/style>
//        &lt;script type=&quot;text/javascript&quot; data-lets-plot-script=&quot;library&quot; src=&quot;https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.8.2/js-package/distr/lets-plot.min.js&quot;>&lt;/script>
//    &lt;/head>
//    &lt;body>
//           &lt;div id=&quot;0htfKb&quot; >&lt;/div>
//    &lt;script type=&quot;text/javascript&quot; data-lets-plot-script=&quot;plot&quot;>
//
//    (function() {
//    // ----------
//
//    const forceImmediateRender = false;
//    const responsive = false;
//
//    let sizing = {
//        width_mode: &quot;FIXED&quot;,
//        height_mode: &quot;FIXED&quot;,
//        width: 700.0,
//        height: 1600.0
//    };
//
//    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
//    if (preferredWidth !== undefined) {
//        sizing = {
//            width_mode: 'FIXED',
//            height_mode: 'SCALED',
//            width: parseFloat(preferredWidth)
//        };
//    }
//
//    const containerDiv = document.getElementById(&quot;0htfKb&quot;);
//    let fig = null;
//
//    function renderPlot() {
//        if (fig === null) {
//            const plotSpec = {
// &quot;ggtitle&quot;:{
// &quot;text&quot;:&quot;Label weights in SFA component \&quot;sf5\&quot;&quot;
// },
// &quot;mapping&quot;:{
// },
// &quot;data&quot;:{
// },
// &quot;ggsize&quot;:{
// &quot;width&quot;:700.0,
// &quot;height&quot;:1600.0
// },
// &quot;kind&quot;:&quot;plot&quot;,
// &quot;scales&quot;:[{
// &quot;aesthetic&quot;:&quot;y&quot;,
// &quot;discrete&quot;:true,
// &quot;name&quot;:&quot;label&quot;
// },{
// &quot;aesthetic&quot;:&quot;x&quot;,
// &quot;name&quot;:&quot;loading&quot;,
// &quot;limits&quot;:[null,null]
// },{
// &quot;aesthetic&quot;:&quot;fill&quot;,
// &quot;scale_mapper_kind&quot;:&quot;color_gradient2&quot;,
// &quot;high&quot;:&quot;#ee6666&quot;,
// &quot;low&quot;:&quot;#5470c6&quot;,
// &quot;name&quot;:&quot;loading&quot;,
// &quot;mid&quot;:&quot;#ffffff&quot;,
// &quot;midpoint&quot;:0.0,
// &quot;limits&quot;:[null,null]
// }],
// &quot;layers&quot;:[{
// &quot;mapping&quot;:{
// &quot;y&quot;:&quot;y&quot;,
// &quot;x&quot;:&quot;x&quot;,
// &quot;fill&quot;:&quot;fill&quot;
// },
// &quot;stat&quot;:&quot;identity&quot;,
// &quot;orientation&quot;:&quot;y&quot;,
// &quot;data&quot;:{
// &quot;x&quot;:[-0.5708827142468603,-0.483707502003071,-0.45772304441429845,-0.4266377261071379,-0.32163796032923153,-0.257142357326998,-0.25233114930403877,-0.242814686465959,-0.20793348636483647,-0.1712096688003104,-0.13681725459195668,-0.11833214781154625,-0.11481114690543945,-0.11207575707791612,-0.08923588473887897,-0.08179399055677386,-0.07288493305657232,-0.06667680829397742,-0.06603063835148856,-0.044707788300221804,-0.007078714861772709,-9.736552811235223E-4,0.019918550907671,0.020606872239269297,0.031140250000173342,0.0472525450520468,0.04915928892872075,0.05680446901311424,0.05861212435845486,0.07953402328680409,0.08014810762189944,0.08145814027493323,0.08611423480891892,0.08611423480891893,0.08724945547575752,0.09922082944324842,0.10746296240711914,0.10919860014940111,0.11079639371928807,0.11646704136500238,0.1611759002615317,0.16938609970102328,0.17313022047225274,0.17962144254772971,0.18473381670927536,0.18517183162627168,0.18851519113329726,0.1921120086382912,0.21653856374746672,0.22855548814534335,0.23035880006928522,0.23568762097333357,0.2477385664871953,0.25288782983047847,0.2531112549240731,0.2793068300269218,0.2797881607655887,0.3142317157469393,0.3378143770964115,0.3586149998867779,0.3926457722233465,0.39902646557303023,0.40162115632130524,0.40752171904951684,0.43904319105092704,0.5193725788119408,0.801027174581061,0.8660096352052149,0.9087002538663539,1.0806688669427855],
// &quot;y&quot;:[&quot;specific&quot;,&quot;direct experience&quot;,&quot;low concentration&quot;,&quot;non-conceptual&quot;,&quot;auditory&quot;,&quot;sensory&quot;,&quot;lack of agency&quot;,&quot;body&quot;,&quot;measurable&quot;,&quot;objective&quot;,&quot;somatic&quot;,&quot;visual&quot;,&quot;dullness&quot;,&quot;pain&quot;,&quot;phenomena that change over minutes&quot;,&quot;phenomena that change over hours&quot;,&quot;phenomena that change over seconds&quot;,&quot;sounds&quot;,&quot;struggling&quot;,&quot;sleepiness&quot;,&quot;energetic&quot;,&quot;turtles&quot;,&quot;vibrations&quot;,&quot;happiness&quot;,&quot;weird&quot;,&quot;weak sense of self&quot;,&quot;tingling&quot;,&quot;self-esteem&quot;,&quot;satisfaction&quot;,&quot;sense of agency&quot;,&quot;self-criticism&quot;,&quot;self-compassion&quot;,&quot;passivity&quot;,&quot;passivity&quot;,&quot;alertness&quot;,&quot;being challenged&quot;,&quot;dissonance&quot;,&quot;self-judgment&quot;,&quot;attention&quot;,&quot;mental images&quot;,&quot;self-consciousness&quot;,&quot;self-acceptance&quot;,&quot;confusion&quot;,&quot;self-image&quot;,&quot;equanimity wrt negative&quot;,&quot;author referring to themselves&quot;,&quot;harmony&quot;,&quot;paradox&quot;,&quot;calmness&quot;,&quot;vague&quot;,&quot;self-referential&quot;,&quot;high concentration&quot;,&quot;self-reference&quot;,&quot;concentration&quot;,&quot;polarities&quot;,&quot;equanimity wrt opposites&quot;,&quot;focus&quot;,&quot;opposites&quot;,&quot;awareness&quot;,&quot;mystical experience&quot;,&quot;dualities&quot;,&quot;equanimity&quot;,&quot;self-awareness&quot;,&quot;subjective&quot;,&quot;self-perception&quot;,&quot;self-reflection&quot;,&quot;abstract&quot;,&quot;metaphorical&quot;,&quot;mental&quot;,&quot;conceptual&quot;],
// &quot;fill&quot;:[-0.5708827142468603,-0.483707502003071,-0.45772304441429845,-0.4266377261071379,-0.32163796032923153,-0.257142357326998,-0.25233114930403877,-0.242814686465959,-0.20793348636483647,-0.1712096688003104,-0.13681725459195668,-0.11833214781154625,-0.11481114690543945,-0.11207575707791612,-0.08923588473887897,-0.08179399055677386,-0.07288493305657232,-0.06667680829397742,-0.06603063835148856,-0.044707788300221804,-0.007078714861772709,-9.736552811235223E-4,0.019918550907671,0.020606872239269297,0.031140250000173342,0.0472525450520468,0.04915928892872075,0.05680446901311424,0.05861212435845486,0.07953402328680409,0.08014810762189944,0.08145814027493323,0.08611423480891892,0.08611423480891893,0.08724945547575752,0.09922082944324842,0.10746296240711914,0.10919860014940111,0.11079639371928807,0.11646704136500238,0.1611759002615317,0.16938609970102328,0.17313022047225274,0.17962144254772971,0.18473381670927536,0.18517183162627168,0.18851519113329726,0.1921120086382912,0.21653856374746672,0.22855548814534335,0.23035880006928522,0.23568762097333357,0.2477385664871953,0.25288782983047847,0.2531112549240731,0.2793068300269218,0.2797881607655887,0.3142317157469393,0.3378143770964115,0.3586149998867779,0.3926457722233465,0.39902646557303023,0.40162115632130524,0.40752171904951684,0.43904319105092704,0.5193725788119408,0.801027174581061,0.8660096352052149,0.9087002538663539,1.0806688669427855]
// },
// &quot;sampling&quot;:&quot;none&quot;,
// &quot;inherit_aes&quot;:false,
// &quot;position&quot;:&quot;dodge&quot;,
// &quot;geom&quot;:&quot;bar&quot;,
// &quot;data_meta&quot;:{
// &quot;series_annotations&quot;:[{
// &quot;type&quot;:&quot;str&quot;,
// &quot;column&quot;:&quot;y&quot;
// },{
// &quot;type&quot;:&quot;float&quot;,
// &quot;column&quot;:&quot;x&quot;
// },{
// &quot;type&quot;:&quot;float&quot;,
// &quot;column&quot;:&quot;fill&quot;
// }]
// }
// }],
// &quot;spec_id&quot;:&quot;14&quot;
// };
//            fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, containerDiv, sizing);
//        } else {
//            fig.updateView({});
//        }
//    }
//
//    const renderImmediately =
//        forceImmediateRender || (
//            sizing.width_mode === 'FIXED' &amp;&amp;
//            (sizing.height_mode === 'FIXED' || sizing.height_mode === 'SCALED')
//        );
//
//    if (renderImmediately) {
//        renderPlot();
//    }
//
//    if (!renderImmediately || responsive) {
//        // Set up observer for initial sizing or continuous
